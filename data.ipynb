# %% [markdown]
# # **__ Data Preprocessing __**

# %% [markdown]
# ### 1. Download

# %%
import kagglehub

data_path = kagglehub.dataset_download("odedgolden/movielens-1m-dataset")

# %% [markdown]
# ### 2. Explore

# %%
import os
import pandas as pd

os.makedirs("data", exist_ok=True)
columns = ["movieid", "title", "genre"]
movies = pd.read_table(
    data_path + "/movies.dat",
    names=columns,
    sep="::",
    encoding="latin1",
    engine="python",
)
movies["genre"] = movies["genre"].apply(lambda x: x.split("|"))
movies.to_parquet("data/movies.parquet", engine="pyarrow")
movies.head()
# Out:
#    movieid                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                               genre
# 0   [Animation, Children's, Comedy]
# 1  [Adventure, Children's, Fantasy]
# 2                 [Comedy, Romance]
# 3                   [Comedy, Drama]
# 4                          [Comedy]

# %%
columns = ["userid", "movieid", "rating", "timestamp"]
ratings = pd.read_table(
    data_path + "/ratings.dat",
    names=columns,
    sep="::",
    encoding="latin1",
    engine="python",
)
ratings.to_parquet("data/ratings.parquet", engine="pyarrow")
ratings.head()
# Out:
#    userid  movieid  rating  timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
columns = ["userid", "gender", "age", "occupation", "zipcode"]
users = pd.read_table(
    data_path + "/users.dat",
    names=columns,
    sep="::",
    encoding="latin1",
    engine="python",
)
users.to_parquet("data/users.parquet", engine="pyarrow")
users.head()
# Out:
#    userid gender  age  occupation zipcode
# 0       1      F    1          10   48067
# 1       2      M   56          16   70072
# 2       3      M   25          15   55117
# 3       4      M   45           7   02460
# 4       5      M   25          20   55455

# %% [markdown]
# ### 3. Feature Engineering

# %%
import pandas as pd

users = pd.read_parquet("data/users.parquet")
ratings = pd.read_parquet("data/ratings.parquet")
movies = pd.read_parquet("data/movies.parquet")

df = ratings.merge(users, on="userid", how="left").merge(
    movies, on="movieid", how="left"
)
df.head()
# Out:
#    userid  movieid  rating  timestamp gender  age  occupation zipcode  \
# 0       1     1193       5  978300760      F    1          10   48067
# 1       1      661       3  978302109      F    1          10   48067
# 2       1      914       3  978301968      F    1          10   48067
# 3       1     3408       4  978300275      F    1          10   48067
# 4       1     2355       5  978824291      F    1          10   48067
#
#                                     title                             genre
# 0  One Flew Over the Cuckoo's Nest (1975)                           [Drama]
# 1        James and the Giant Peach (1996)  [Animation, Children's, Musical]
# 2                     My Fair Lady (1964)                [Musical, Romance]
# 3                  Erin Brockovich (2000)                           [Drama]
# 4                    Bug's Life, A (1998)   [Animation, Children's, Comedy]

# %%
df["gender"] = df["gender"].astype("category").cat.codes
df["gender"].value_counts()
# Out:
# gender
# 1    753769
# 0    246440
# Name: count, dtype: int64

# %%
df["rating_norm"] = (df["rating"] - 1) / 4
df["rating_binary"] = (df["rating"] > 3).astype(int)
df.head()
# Out:
#    userid  movieid  rating  timestamp  gender  age  occupation zipcode  \
# 0       1     1193       5  978300760       0    1          10   48067
# 1       1      661       3  978302109       0    1          10   48067
# 2       1      914       3  978301968       0    1          10   48067
# 3       1     3408       4  978300275       0    1          10   48067
# 4       1     2355       5  978824291       0    1          10   48067
#
#                                     title                             genre  \
# 0  One Flew Over the Cuckoo's Nest (1975)                           [Drama]
# 1        James and the Giant Peach (1996)  [Animation, Children's, Musical]
# 2                     My Fair Lady (1964)                [Musical, Romance]
# 3                  Erin Brockovich (2000)                           [Drama]
# 4                    Bug's Life, A (1998)   [Animation, Children's, Comedy]
#
#    rating_norm  rating_binary
# 0         1.00              1
# 1         0.50              0
# 2         0.50              0
# 3         0.75              1
# 4         1.00              1

# %%
df = df.drop(columns=["timestamp", "age", "occupation", "zipcode"])

# %%
from sklearn.preprocessing import LabelEncoder

all_genres = [genre for sublist in df["genre"] for genre in sublist]
unique_genres = sorted(list(set(all_genres)))
genre_encoder = LabelEncoder()
genre_encoder.fit(unique_genres)


def encode_genre_list(genre_list, encoder):
    return encoder.transform(genre_list).tolist()


df["genre_list"] = df["genre"].apply(lambda x: encode_genre_list(x, genre_encoder))
df.head()
# Out:
#    userid  movieid  rating  gender                                   title  \
# 0       1     1193       5       0  One Flew Over the Cuckoo's Nest (1975)
# 1       1      661       3       0        James and the Giant Peach (1996)
# 2       1      914       3       0                     My Fair Lady (1964)
# 3       1     3408       4       0                  Erin Brockovich (2000)
# 4       1     2355       5       0                    Bug's Life, A (1998)
#
#                               genre  rating_norm  rating_binary  genre_list
# 0                           [Drama]         1.00              1         [7]
# 1  [Animation, Children's, Musical]         0.50              0  [2, 3, 11]
# 2                [Musical, Romance]         0.50              0    [11, 13]
# 3                           [Drama]         0.75              1         [7]
# 4   [Animation, Children's, Comedy]         1.00              1   [2, 3, 4]

# %%
df = df.drop(columns=["genre", "title", "rating"])
df_shuffled = df.sample(frac=1)
df_shuffled.head()
# Out:
#         userid  movieid  gender  rating_norm  rating_binary genre_list
# 980082    5915     1100       1         0.50              0    [0, 13]
# 984880    5950     2779       1         0.50              0        [4]
# 309006    1837     2020       1         0.75              1    [7, 13]
# 337341    1984     1263       1         0.75              1    [7, 16]
# 225966    1369     1294       1         0.75              1    [4, 16]

# %%
df_shuffled.to_parquet("data/preprocessed.parquet", engine="pyarrow")
